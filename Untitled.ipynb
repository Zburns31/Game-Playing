# %%
# importing show from bokeh.io
from bokeh.io import show, output_notebook
output_notebook()
  
# importing Button from bokeh.models
# module
from bokeh.models import Button
  
# importing row from bokeh.layouts module
# so that buttons can be shown side by side
from bokeh.layouts import row, column, grid
  
# Creating a list of buttons with defining different properties
# in each of the buttons
buttons = [Button(label="Button 1", button_type="danger"),
            Button(label='Button 2', button_type='success', width=200, height=60),
                Button(label='Button 3', button_type='primary', width=100, height=100)]
  
# Showing all the buttons rowwise
show(row(buttons), notebook_handle = True)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1018">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="6907a2f1-0af8-4d50-b612-d0148d6e064f" data-root-id="1022"></div>
# <p><code>&lt;Bokeh Notebook handle for <strong>In[5]</strong>&gt;</code></p>

# %%
LENGTH = 3
WIDTH = 3

r1_buttons = [
    Button(
        label = f"Button {n}", 
        button_type="default",
        # Margin-top, MR, MB, ML
        margin = (5,5,1,5), 
        width = 10,
        height = 10
    ) for n in range(WIDTH)
]

r2_buttons = [
    Button(
        label = f"Button {n}", 
        button_type="default",
        # Margin-top, MR, MB, ML
#         margin = (5,5,1,5), 
#         width = 15,
#         height = 15
    ) for n in range(WIDTH)
]

r3_buttons = [
    Button(
        label = f"Button {n}", 
        button_type="default",
        # Margin-top, MR, MB, ML
#         margin = (5,5,1,5), 
#         width = 15,
#         height = 15
    ) for n in range(WIDTH)
]

grid_layout = grid(
    [
        r1_buttons,
#         r2_buttons,
#         r3_buttons
    ],
#     sizing_mode = 'stretch_both'
)

show(grid_layout)
# Out:
#   <div class="bk-root" id="949a2605-827e-476c-9f22-20af95868c14" data-root-id="1387"></div>
